# %%
import pandas as pd
import numpy as np
import networkx as nx
import cPickle as pickle
from model.utilities import haversine, diff_timestamps, earliest_target

# Reading in static schedule data
stops_full = pd.read_csv('data/google_transit/stops.txt', index_col='stop_id')
routes = pd.read_csv('data/google_transit/routes.txt', index_col='route_id')
trips = pd.read_csv('data/google_transit/trips.txt', index_col='trip_id')
stop_times = pd.read_csv('data/google_transit/stop_times.txt')
shapes = pd.read_csv('data/google_transit/shapes.txt')

# Some of these stops are named "Not a public stop" but are still in trips.
# Luckily, in the few trips they appear in, they're only either at the
# beginning or the end, so we can remove them now and we'll still build
# a nice graph with the connections we expect.
stops = stops_full[~stops_full.index.isin([7520, 7530, 7531, 7540])]
stop_times = stop_times[~stop_times['stop_id'].isin([7520, 7530, 7531, 7540])]

# Oh and some stops are in stops.txt but not used in trips... let's remove 'em
used_stops = set(stop_times['stop_id'].unique())
stops = stops[stops.index.isin(used_stops)]

# Let's make some sorted stop-timepoint lists for each stop_id to
# make lookup faster for things
all_stop_timepoints = {}
for stopid in used_stops:
    node_names = stop_times[stop_times['stop_id'] == stopid].\
                    apply(lambda x: '{0}_{1}'.\
                              format(stopid, x['arrival_time']),\
                          axis=1)
    all_stop_timepoints[stopid] = sorted(list(set(node_names)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b11bc226b5f2> in <module>()
#       3 import networkx as nx
#       4 import cPickle as pickle
# ----> 5 from model.utilities import haversine, diff_timestamps, earliest_target
#       6
#       7 # Reading in static schedule data
#
# ImportError: cannot import name earliest_target

# %%
G_x = nx.read_gpickle('graph_x_7.gpkl')

# %%
sat_edges = [(u, v, d) for u,v,d in G_x.edges_iter(data=True) if d.get('service_id', 0) == 2]
sun_edges = [(u, v, d) for u,v,d in G_x.edges_iter(data=True) if d.get('service_id', 0) == 3]
w_edges = [(u, v, d) for u,v,d in G_x.edges_iter(data=True) if d.get('service_id', 0) == 1]

# %%
all_stop_timepoints[4203][21]
# Out:
# '4203_09:53:03'

# %%
G_x.remove_edges_from(sat_edges)
G_x.remove_edges_from(sun_edges)

# %%
path_time, path = earliest_target('3335_07:42:08', 4555, 3600, G_x, all_stop_timepoints)

# %%
path_time/60.
# Out:
# 51.083333333333336

# %%
path
# Out:
# ['3335_07:42:08',
#  '3336_07:46:47',
#  '3329_07:48:01',
#  '3326_07:49:00',
#  '3341_07:49:56',
#  '3345_07:51:00',
#  '3323_07:52:13',
#  '3331_07:53:17',
#  '3334_07:54:23',
#  '3349_07:55:27',
#  '5553_07:57:00',
#  '3292_07:58:40',
#  '3299_08:00:13',
#  '3289_08:01:32',
#  '3282_08:03:00',
#  '3296_08:04:07',
#  '6029_08:05:00',
#  '6031_08:06:10',
#  '6033_08:07:20',
#  '7809_08:09:05',
#  '3454_08:15:52',
#  '3454_08:16:07',
#  '3456_08:16:46',
#  '6197_08:20:00',
#  '6198_08:20:20',
#  '6199_08:20:47',
#  '6200_08:21:16',
#  '3517_08:21:38',
#  '6962_08:22:12',
#  '3513_08:22:34',
#  '3505_08:23:02',
#  '4130_08:23:26',
#  '4132_08:24:00',
#  '4549_08:24:40',
#  '4557_08:25:25',
#  '4562_08:26:24',
#  '7285_08:27:47',
#  '4560_08:28:33',
#  '3123_08:30:00',
#  '4555_08:33:13']

# %%
simple_path = []
last_step = 0
for i in xrange(len(path) - 1):
    route = G_x[path[i]][path[i+1]].get('route_id', 'walk')
    if route != 'walk':
        route = routes.loc[route]['route_short_name']
    if True:#route != last_step:
        print '{0}: {1} to {2}'.\
                    format(G_x.node[path[i]]['arrival_time'], \
                           route, G_x.node[path[i+1]]['stop_name'])
    last_step = route
# Out:
# 07:42:08: walk to 18th St & Hattie St
# 07:46:47: 33 to 18th St & Diamond St
# 07:48:01: 33 to 18th St & Castro St
# 07:49:00: 33 to 18th St & Noe St
# 07:49:56: 33 to 18th St & Sanchez St
# 07:51:00: 33 to 18th St & Church St
# 07:52:13: 33 to 18th St & Dolores St
# 07:53:17: 33 to 18th St & Guerrero St
# 07:54:23: 33 to 18th St & Valencia St
# 07:55:27: 33 to Mission St & 18th St
# 07:57:00: 33 to 16th St & Mission St
# 07:58:40: 33 to 16th St & Shotwell St
# 08:00:13: 33 to 16th St & Harrison St
# 08:01:32: 33 to 16th St & Bryant St
# 08:03:00: 33 to 16th St & Potrero Ave
# 08:04:07: 33 to Potrero Ave & 17th St
# 08:05:00: 33 to Potrero Ave & 18th St
# 08:06:10: 33 to Potrero Ave & 20th St
# 08:07:20: 33 to Sf General Hospital
# 08:09:05: walk to 23rd St & Utah St
# 08:15:52: walk to 23rd St & Utah St
# 08:16:07: 10 to 23rd St & Vermont St
# 08:16:46: walk to Rhode Island St & 23rd St
# 08:20:00: 19 to Rhode Island St & 24th St
# 08:20:20: 19 to Rhode Island St & 25th St
# 08:20:47: 19 to Rhode Island St & 26th St
# 08:21:16: 19 to 26th St & De Haro St
# 08:21:38: 19 to Wisconsin St & 26th St
# 08:22:12: 19 to 25th St & Wisconsin St
# 08:22:34: 19 to 25th St & Connecticut St
# 08:23:02: 19 to Connecticut St & 26th St
# 08:23:26: 19 to Connecticut St & Cesar Chavez St
# 08:24:00: 19 to Evans Ave & Cesar Chavez St
# 08:24:40: 19 to Evans Ave & Napoleon St
# 08:25:25: 19 to Evans Ave & Selby St
# 08:26:24: 19 to Evans Ave & Quint St
# 08:27:47: 19 to Evans Ave & Phelps St
# 08:28:33: walk to 3rd St & Evans Ave
# 08:30:00: walk to Evans Ave & Newhall St

# %%
stops.loc[3335], stops.loc[4555]
# Out:
# (stop_name    18th St & Hattie St
#  stop_desc
#  stop_lat                 37.7606
#  stop_lon                -122.441
#  zone_id
#  stop_url
#  Name: 3335, dtype: object, stop_name    Evans Ave & Newhall St
#  stop_desc
#  stop_lat                    37.7419
#  stop_lon                   -122.386
#  zone_id
#  stop_url
#  Name: 4555, dtype: object)

# %%
routes[routes['route_short_name'] == 'KT']
# Out:
#          agency_id route_short_name  route_long_name route_desc  route_type  \
# route_id
# 11397        SFMTA               KT  INGLESIDE/THIRD                      0
#
#          route_url route_color route_text_color
# route_id
# 11397

# %%
trips[trips['route_id'] == 11397]
# Out:
#          route_id  service_id         trip_headsign  direction_id  block_id  \
# trip_id
# 7069264     11397           3   West Portal Station             1      9403
# 7069263     11397           3   West Portal Station             1      9403
# 7069262     11397           3   West Portal Station             1      9403
# 7069261     11397           3   West Portal Station             1      9401
# 7069260     11397           3   West Portal Station             1      9401
# 7069259     11397           3   West Portal Station             1      9401
# 7069258     11397           3   West Portal Station             1      9401
# 7065914     11397           1   West Portal Station             1      9501
# 7065913     11397           1   West Portal Station             1      9402
# 7071692     11397           2   Embarcadero Station             1      9401
# 7065800     11397           1   Embarcadero Station             1      9402
# 7065847     11397           1  Sunnydale + Bayshore             1      9414
# 7065846     11397           1  Sunnydale + Bayshore             1      9401
# 7065845     11397           1  Sunnydale + Bayshore             1      9412
# 7065844     11397           1  Sunnydale + Bayshore             1      9416
# 7065843     11397           1  Sunnydale + Bayshore             1      9402
# 7065842     11397           1  Sunnydale + Bayshore             1      9410
# 7065841     11397           1  Sunnydale + Bayshore             1      9413
# 7065840     11397           1  Sunnydale + Bayshore             1      9408
# 7065839     11397           1  Sunnydale + Bayshore             1      9423
# 7065838     11397           1  Sunnydale + Bayshore             1      9406
# 7065837     11397           1  Sunnydale + Bayshore             1      9411
# 7065836     11397           1  Sunnydale + Bayshore             1      9422
# 7065835     11397           1  Sunnydale + Bayshore             1      9404
# 7065834     11397           1  Sunnydale + Bayshore             1      9409
# 7065833     11397           1  Sunnydale + Bayshore             1      9407
# 7065832     11397           1  Sunnydale + Bayshore             1      9405
# 7065831     11397           1  Sunnydale + Bayshore             1      9417
# 7065830     11397           1  Sunnydale + Bayshore             1      9421
# 7065829     11397           1  Sunnydale + Bayshore             1      9403
# ...           ...         ...                   ...           ...       ...
# 7071801     11397           2    23rd St + Third St             1      9503
# 7071795     11397           2    23rd St + Third St             1      9502
# 7069274     11397           3    23rd St + Third St             1      9602
# 7069271     11397           3    23rd St + Third St             1      9304
# 7069255     11397           3    23rd St + Third St             1      9508
# 7069254     11397           3    23rd St + Third St             1      9507
# 7065941     11397           1    23rd St + Third St             1      9605
# 7065940     11397           1    23rd St + Third St             1      9301
# 7065938     11397           1    23rd St + Third St             1      9505
# 7065930     11397           1    23rd St + Third St             1      9611
# 7065929     11397           1    23rd St + Third St             1      9609
# 7065928     11397           1    23rd St + Third St             1      9602
# 7065927     11397           1    23rd St + Third St             1      9511
# 7065926     11397           1    23rd St + Third St             1      9510
# 7065923     11397           1    23rd St + Third St             1      9503
# 7065922     11397           1    23rd St + Third St             1      9504
# 7065920     11397           1    23rd St + Third St             1      9521
# 7065919     11397           1    23rd St + Third St             1      9506
# 7071800     11397           2  Sunnydale + Bayshore             1      9417
# 7071798     11397           2  Sunnydale + Bayshore             1      9415
# 7071797     11397           2  Sunnydale + Bayshore             1      9413
# 7071796     11397           2  Sunnydale + Bayshore             1      9412
# 7071697     11397           2  Sunnydale + Bayshore             1      9409
# 7071696     11397           2  Sunnydale + Bayshore             1      9406
# 7069253     11397           3  Sunnydale + Bayshore             1      9416
# 7069252     11397           3  Sunnydale + Bayshore             1      9409
# 7069248     11397           3  Sunnydale + Bayshore             1      9408
# 7069247     11397           3  Sunnydale + Bayshore             1      9407
# 7069246     11397           3  Sunnydale + Bayshore             1      9406
# 7069245     11397           3  Sunnydale + Bayshore             1      9405
#
#          shape_id
# trip_id
# 7069264    138563
# 7069263    138563
# 7069262    138563
# 7069261    138563
# 7069260    138563
# 7069259    138563
# 7069258    138563
# 7065914    138563
# 7065913    138563
# 7071692    138565
# 7065800    138565
# 7065847    138560
# 7065846    138560
# 7065845    138560
# 7065844    138560
# 7065843    138560
# 7065842    138560
# 7065841    138560
# 7065840    138560
# 7065839    138560
# 7065838    138560
# 7065837    138560
# 7065836    138560
# 7065835    138560
# 7065834    138560
# 7065833    138560
# 7065832    138560
# 7065831    138560
# 7065830    138560
# 7065829    138560
# ...           ...
# 7071801    138568
# 7071795    138568
# 7069274    138568
# 7069271    138568
# 7069255    138568
# 7069254    138568
# 7065941    138568
# 7065940    138568
# 7065938    138568
# 7065930    138568
# 7065929    138568
# 7065928    138568
# 7065927    138568
# 7065926    138568
# 7065923    138568
# 7065922    138568
# 7065920    138568
# 7065919    138568
# 7071800    138570
# 7071798    138570
# 7071797    138570
# 7071796    138570
# 7071697    138570
# 7071696    138570
# 7069253    138570
# 7069252    138570
# 7069248    138570
# 7069247    138570
# 7069246    138570
# 7069245    138570
#
# [766 rows x 6 columns]

# %%
foo = nx.all_shortest_paths(G_x, '3335_07:42:08','4555_08:33:13', weight='duration')

# %%
foo.next()
# Out:
# ['3335_07:42:08',
#  '3336_07:46:47',
#  '3329_07:48:01',
#  '3326_07:49:00',
#  '4315_07:50:44',
#  '4316_07:51:15',
#  '4318_07:51:52',
#  '3414_07:52:17',
#  '3415_07:52:51',
#  '4538_07:53:28',
#  '4444_07:54:43',
#  '4443_07:55:39',
#  '3465_07:56:22',
#  '4372_07:56:55',
#  '4390_07:57:13',
#  '4375_07:57:36',
#  '7290_08:00:30',
#  '3521_08:01:22',
#  '5732_08:02:09',
#  '5734_08:02:53',
#  '5736_08:03:42',
#  '5738_08:04:27',
#  '3544_08:05:16',
#  '3536_08:06:08',
#  '3538_08:07:01',
#  '3541_08:08:00',
#  '4157_08:08:56',
#  '4161_08:09:36',
#  '4150_08:10:07',
#  '4146_08:10:31',
#  '4143_08:11:19',
#  '4152_08:12:03',
#  '4154_08:12:29',
#  '4159_08:13:03',
#  '7213_08:13:49',
#  '4148_08:15:00',
#  '5093_08:15:48',
#  '5094_08:16:52',
#  '5095_08:17:49',
#  '5884_08:18:50',
#  '5882_08:19:34',
#  '5880_08:20:21',
#  '5878_08:20:23',
#  '3141_08:22:00',
#  '7402_08:23:00',
#  '7403_08:24:21',
#  '7404_08:25:17',
#  '7352_08:26:26',
#  '4555_08:33:13']

# %%
p1 = ['3335_07:42:08', '3336_07:46:47', '3329_07:48:01', '3326_07:49:00', '4315_07:50:44', '4316_07:51:15', '4318_07:51:52', '3414_07:52:17', '3415_07:52:51', '4538_07:53:28', '4444_07:54:43', '4443_07:55:39', '3465_07:56:22', '4372_07:56:55', '4390_07:57:13', '4375_07:57:36', '7290_08:00:30', '3521_08:01:22', '5732_08:02:09', '5734_08:02:53', '5736_08:03:42', '5738_08:04:27', '3544_08:05:16', '3536_08:06:08', '3538_08:07:01', '3541_08:08:00', '4157_08:08:56', '4161_08:09:36', '4150_08:10:07', '4146_08:10:31', '4143_08:11:19', '4152_08:12:03', '4154_08:12:29', '4159_08:13:03', '7213_08:13:49', '4148_08:15:00', '5093_08:15:48', '5094_08:16:52', '5095_08:17:49', '5884_08:18:50', '5882_08:19:34', '5880_08:20:21', '5878_08:20:23', '3141_08:22:00', '7402_08:23:00', '7403_08:24:21', '7404_08:25:17', '7352_08:26:26', '4555_08:33:13']

# %%
print path
# Out:
# ['3335_07:42:08', '3336_07:46:47', '3329_07:48:01', '3326_07:49:00', '3341_07:49:56', '3345_07:51:00', '3323_07:52:13', '3331_07:53:17', '3334_07:54:23', '3349_07:55:27', '5553_07:57:00', '3292_07:58:40', '3299_08:00:13', '3289_08:01:32', '3282_08:03:00', '3296_08:04:07', '6029_08:05:00', '6031_08:06:10', '6033_08:07:20', '7809_08:09:05', '3454_08:15:52', '3454_08:16:07', '3456_08:16:46', '6197_08:20:00', '6198_08:20:20', '6199_08:20:47', '6200_08:21:16', '3517_08:21:38', '6962_08:22:12', '3513_08:22:34', '3505_08:23:02', '4130_08:23:26', '4132_08:24:00', '4549_08:24:40', '4557_08:25:25', '4562_08:26:24', '7285_08:27:47', '4560_08:28:33', '3123_08:30:00', '4555_08:33:13']

# %%
[s for s in stops['stop_name'] if s.find('Castro') > -1]
# Out:
# ['14th St & Castro St',
#  '14th St & Castro St',
#  '17th St & Castro St',
#  '18th St & Castro St',
#  '18th St & Castro St',
#  '24th St & Castro St',
#  '24th St & Castro St',
#  '26th St & Castro St',
#  'Chenery St & Castro St',
#  'Castro St & 14th St',
#  'Castro St & 14th St',
#  'Castro St & 15th St',
#  'Castro St & 15th St',
#  'Castro St & 16th St',
#  'Castro St & 16th St',
#  'Castro St & 17th St',
#  'Castro St & 18th St',
#  'Castro St & 18th St',
#  'Castro St & 19th St',
#  'Castro St & 19th St',
#  'Castro St & 20th St',
#  'Castro St & 20th St',
#  'Castro St & 21st St',
#  'Castro St & 21st St',
#  'Castro St & 22nd St',
#  'Castro St & 22nd St',
#  'Castro St & 23rd St',
#  'Castro St & 23rd St',
#  'Castro St & 24th St',
#  'Castro St & 24th St',
#  'Castro St & 25th St',
#  'Castro St & 25th St',
#  'Castro St & Duboce Ave',
#  'Castro St & Duboce Ave',
#  'Castro St & Elizabeth St',
#  'Castro St & Elizabeth St',
#  'Castro St & Market St',
#  'Market St & Castro St',
#  'Metro Castro Station/Downtown',
#  'Metro Castro Station/Outbound',
#  'Market St & Castro St',
#  'Castro St & 26th St']

# %%
stops[stops['stop_name'] == 'Metro Castro Station/Downtown']
# Out:
#                              stop_name stop_desc  stop_lat    stop_lon  \
# stop_id
# 5728     Metro Castro Station/Downtown            37.76262 -122.435231
#
#         zone_id stop_url
# stop_id
# 5728

# %%
stop_times[stop_times['stop_id'] == 5728]['trip_id'].head(10)
# Out:
# 1028342    7064267
# 1028372    7064268
# 1028402    7064269
# 1028432    7064270
# 1028462    7064271
# 1028492    7064272
# 1028522    7064273
# 1028552    7064274
# 1028582    7064275
# 1028612    7064276
# Name: trip_id, dtype: int64

# %%
trips.loc[7064276]
# Out:
# route_id                       11398
# service_id                         1
# trip_headsign    Embarcadero Station
# direction_id                       1
# block_id                        9504
# shape_id                      138573
# Name: 7064276, dtype: object

# %%
routes.loc[11398]
# Out:
# agency_id             SFMTA
# route_short_name          L
# route_long_name     TARAVAL
# route_desc
# route_type                0
# route_url
# route_color
# route_text_color
# Name: 11398, dtype: object
